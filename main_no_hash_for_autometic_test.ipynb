# %%
import audioidentification_nohash as aid
targetDir = 'database_recordings'
queryDir = 'query_recordings'
fingerprintDir = 'fingerprint'
output_file = 'output_nohash.txt'

# %%
# Generate fingerprint of the target databases. If the fingerprint exists, it will load that directly instead of generating

aid.fingerprintBuilder(targetDir, fingerprintDir)
# Out:
# C:\Users\xiede\OneDrive\MisterDK\Queen Mary University of London\Courses\Music Informatics\Assignment\02.Audio Identification\audioidentification_nohash.py:146: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   coordinates = peak_local_max(np.log(D), min_distance=min_distance, threshold_rel=0.05, indices=False)
# Generating fingerprints 1/200...
# Generating fingerprints 2/200...
# Generating fingerprints 3/200...
# Generating fingerprints 4/200...
# Generating fingerprints 5/200...
# Generating fingerprints 6/200...
# Generating fingerprints 7/200...
# Generating fingerprints 8/200...
# Generating fingerprints 9/200...
# Generating fingerprints 10/200...
# Generating fingerprints 11/200...
# Generating fingerprints 12/200...
# Generating fingerprints 13/200...
# Generating fingerprints 14/200...
# ...

# %%
# Generate fingerprint of the query data to match. If the fingerprint exists, it will load that directly instead of generating
# Also, the idetification results will be produced in .txt file

aid.audioIdentification(queryDir, fingerprintDir, output_file)
# Out:
# C:\Users\xiede\OneDrive\MisterDK\Queen Mary University of London\Courses\Music Informatics\Assignment\02.Audio Identification\audioidentification_nohash.py:146: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   coordinates = peak_local_max(np.log(D), min_distance=min_distance, threshold_rel=0.05, indices=False)
# Generating query fingerprints 1/213...
# Generating query fingerprints 2/213...
# Generating query fingerprints 3/213...
# Generating query fingerprints 4/213...
# Generating query fingerprints 5/213...
# Generating query fingerprints 6/213...
# Generating query fingerprints 7/213...
# Generating query fingerprints 8/213...
# Generating query fingerprints 9/213...
# Generating query fingerprints 10/213...
# Generating query fingerprints 11/213...
# Generating query fingerprints 12/213...
# ...
