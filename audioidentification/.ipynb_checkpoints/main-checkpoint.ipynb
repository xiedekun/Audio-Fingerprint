# %%
import audioidentification as aid
targetDir = 'database_recordings'
queryDir = 'query_recordings'
fingerprintDir = 'fingerprint'
output_file = 'output.txt'

# %%
# Generate fingerprint of the target databases. If the fingerprint exists, it will load that directly instead of generating

aid.fingerprintBuilder(targetDir, fingerprintDir)
# Out:
# C:\Users\xiede\OneDrive\MisterDK\Queen Mary University of London\Courses\Music Informatics\Assignment\02.Audio Identification\audioidentification.py:113: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   coordinates = peak_local_max(np.log(D), min_distance=min_distance, threshold_rel=0.05, indices=False)
# Generating Contellation Map 1/200...
# Generating Contellation Map 2/200...
# Generating Contellation Map 3/200...
# Generating Contellation Map 4/200...
# Generating Contellation Map 5/200...
# Generating Contellation Map 6/200...
# Generating Contellation Map 7/200...
# Generating Contellation Map 8/200...
# Generating Contellation Map 9/200...
# Generating Contellation Map 10/200...
# Generating Contellation Map 11/200...
# Generating Contellation Map 12/200...
# Generating Contellation Map 13/200...
# Generating Contellation Map 14/200...
# Generating Contellation Map 15/200...
# Generating Contellation Map 16/200...
# Generating Contellation Map 17/200...
# Generating Contellation Map 18/200...
# Generating Contellation Map 19/200...
# Generating Contellation Map 20/200...
# Generating Contellation Map 21/200...
# Generating Contellation Map 22/200...
# Generating Contellation Map 23/200...
# Generating Contellation Map 24/200...
# Generating Contellation Map 25/200...
# Generating Contellation Map 26/200...
# Generating Contellation Map 27/200...
# Generating Contellation Map 28/200...
# Generating Contellation Map 29/200...
# Generating Contellation Map 30/200...
# Generating Contellation Map 31/200...
# Generating Contellation Map 32/200...
# Generating Contellation Map 33/200...
# Generating Contellation Map 34/200...
# Generating Contellation Map 35/200...
# Generating Contellation Map 36/200...
# Generating Contellation Map 37/200...
# Generating Contellation Map 38/200...
# Generating Contellation Map 39/200...
# Generating Contellation Map 40/200...
# Generating Contellation Map 41/200...
# Generating Contellation Map 42/200...
# Generating Contellation Map 43/200...
# Generating Contellation Map 44/200...
# Generating Contellation Map 45/200...
# Generating Contellation Map 46/200...
# Generating Contellation Map 47/200...
# Generating Contellation Map 48/200...
# Generating Contellation Map 49/200...
# Generating Contellation Map 50/200...
# Generating Contellation Map 51/200...
# Generating Contellation Map 52/200...
# Generating Contellation Map 53/200...
# Generating Contellation Map 54/200...
# Generating Contellation Map 55/200...
# C:\Users\xiede\OneDrive\MisterDK\Queen Mary University of London\Courses\Music Informatics\Assignment\02.Audio Identification\audioidentification.py:113: RuntimeWarning: divide by zero encountered in log
#   coordinates = peak_local_max(np.log(D), min_distance=min_distance, threshold_rel=0.05, indices=False)
# Generating Contellation Map 56/200...
# Generating Contellation Map 57/200...
# Generating Contellation Map 58/200...
# Generating Contellation Map 59/200...
# Generating Contellation Map 60/200...
# Generating Contellation Map 61/200...
# Generating Contellation Map 62/200...
# Generating Contellation Map 63/200...
# Generating Contellation Map 64/200...
# Generating Contellation Map 65/200...
# Generating Contellation Map 66/200...
# Generating Contellation Map 67/200...
# Generating Contellation Map 68/200...
# Generating Contellation Map 69/200...
# Generating Contellation Map 70/200...
# Generating Contellation Map 71/200...
# Generating Contellation Map 72/200...
# Generating Contellation Map 73/200...
# Generating Contellation Map 74/200...
# Generating Contellation Map 75/200...
# Generating Contellation Map 76/200...
# Generating Contellation Map 77/200...
# Generating Contellation Map 78/200...
# Generating Contellation Map 79/200...
# Generating Contellation Map 80/200...
# Generating Contellation Map 81/200...
# Generating Contellation Map 82/200...
# Generating Contellation Map 83/200...
# Generating Contellation Map 84/200...
# Generating Contellation Map 85/200...
# Generating Contellation Map 86/200...
# Generating Contellation Map 87/200...
# Generating Contellation Map 88/200...
# Generating Contellation Map 89/200...
# Generating Contellation Map 90/200...
# Generating Contellation Map 91/200...
# Generating Contellation Map 92/200...
# Generating Contellation Map 93/200...
# Generating Contellation Map 94/200...
# Generating Contellation Map 95/200...
# Generating Contellation Map 96/200...
# Generating Contellation Map 97/200...
# Generating Contellation Map 98/200...
# Generating Contellation Map 99/200...
# Generating Contellation Map 100/200...
# Generating Contellation Map 101/200...
# Generating Contellation Map 102/200...
# Generating Contellation Map 103/200...
# Generating Contellation Map 104/200...
# Generating Contellation Map 105/200...
# Generating Contellation Map 106/200...
# Generating Contellation Map 107/200...
# Generating Contellation Map 108/200...
# Generating Contellation Map 109/200...
# Generating Contellation Map 110/200...
# Generating Contellation Map 111/200...
# Generating Contellation Map 112/200...
# Generating Contellation Map 113/200...
# Generating Contellation Map 114/200...
# Generating Contellation Map 115/200...
# Generating Contellation Map 116/200...
# Generating Contellation Map 117/200...
# Generating Contellation Map 118/200...
# Generating Contellation Map 119/200...
# Generating Contellation Map 120/200...
# Generating Contellation Map 121/200...
# Generating Contellation Map 122/200...
# Generating Contellation Map 123/200...
# Generating Contellation Map 124/200...
# Generating Contellation Map 125/200...
# Generating Contellation Map 126/200...
# Generating Contellation Map 127/200...
# Generating Contellation Map 128/200...
# Generating Contellation Map 129/200...
# Generating Contellation Map 130/200...
# Generating Contellation Map 131/200...
# Generating Contellation Map 132/200...
# Generating Contellation Map 133/200...
# Generating Contellation Map 134/200...
# Generating Contellation Map 135/200...
# Generating Contellation Map 136/200...
# Generating Contellation Map 137/200...
# Generating Contellation Map 138/200...
# Generating Contellation Map 139/200...
# Generating Contellation Map 140/200...
# Generating Contellation Map 141/200...
# Generating Contellation Map 142/200...
# Generating Contellation Map 143/200...
# Generating Contellation Map 144/200...
# Generating Contellation Map 145/200...
# Generating Contellation Map 146/200...
# Generating Contellation Map 147/200...
# Generating Contellation Map 148/200...
# Generating Contellation Map 149/200...
# Generating Contellation Map 150/200...
# Generating Contellation Map 151/200...
# Generating Contellation Map 152/200...
# Generating Contellation Map 153/200...
# Generating Contellation Map 154/200...
# Generating Contellation Map 155/200...
# Generating Contellation Map 156/200...
# Generating Contellation Map 157/200...
# Generating Contellation Map 158/200...
# Generating Contellation Map 159/200...
# Generating Contellation Map 160/200...
# Generating Contellation Map 161/200...
# Generating Contellation Map 162/200...
# Generating Contellation Map 163/200...
# Generating Contellation Map 164/200...
# Generating Contellation Map 165/200...
# Generating Contellation Map 166/200...
# Generating Contellation Map 167/200...
# Generating Contellation Map 168/200...
# Generating Contellation Map 169/200...
# Generating Contellation Map 170/200...
# Generating Contellation Map 171/200...
# Generating Contellation Map 172/200...
# Generating Contellation Map 173/200...
# Generating Contellation Map 174/200...
# Generating Contellation Map 175/200...
# Generating Contellation Map 176/200...
# Generating Contellation Map 177/200...
# Generating Contellation Map 178/200...
# Generating Contellation Map 179/200...
# Generating Contellation Map 180/200...
# Generating Contellation Map 181/200...
# Generating Contellation Map 182/200...
# Generating Contellation Map 183/200...
# Generating Contellation Map 184/200...
# Generating Contellation Map 185/200...
# Generating Contellation Map 186/200...
# Generating Contellation Map 187/200...
# Generating Contellation Map 188/200...
# Generating Contellation Map 189/200...
# Generating Contellation Map 190/200...
# Generating Contellation Map 191/200...
# Generating Contellation Map 192/200...
# Generating Contellation Map 193/200...
# Generating Contellation Map 194/200...
# Generating Contellation Map 195/200...
# Generating Contellation Map 196/200...
# Generating Contellation Map 197/200...
# Generating Contellation Map 198/200...
# Generating Contellation Map 199/200...
# Generating Contellation Map 200/200...
# Generating Hash 1/200...
# Generating Hash 2/200...
# Generating Hash 3/200...
# Generating Hash 4/200...
# Generating Hash 5/200...
# Generating Hash 6/200...
# Generating Hash 7/200...
# Generating Hash 8/200...
# Generating Hash 9/200...
# Generating Hash 10/200...
# Generating Hash 11/200...
# Generating Hash 12/200...
# Generating Hash 13/200...
# Generating Hash 14/200...
# Generating Hash 15/200...
# Generating Hash 16/200...
# Generating Hash 17/200...
# Generating Hash 18/200...
# Generating Hash 19/200...
# Generating Hash 20/200...
# Generating Hash 21/200...
# Generating Hash 22/200...
# Generating Hash 23/200...
# Generating Hash 24/200...
# Generating Hash 25/200...
# Generating Hash 26/200...
# Generating Hash 27/200...
# Generating Hash 28/200...
# Generating Hash 29/200...
# Generating Hash 30/200...
# Generating Hash 31/200...
# Generating Hash 32/200...
# Generating Hash 33/200...
# Generating Hash 34/200...
# Generating Hash 35/200...
# Generating Hash 36/200...
# Generating Hash 37/200...
# Generating Hash 38/200...
# Generating Hash 39/200...
# Generating Hash 40/200...
# Generating Hash 41/200...
# Generating Hash 42/200...
# Generating Hash 43/200...
# Generating Hash 44/200...
# Generating Hash 45/200...
# Generating Hash 46/200...
# Generating Hash 47/200...
# Generating Hash 48/200...
# Generating Hash 49/200...
# Generating Hash 50/200...
# Generating Hash 51/200...
# Generating Hash 52/200...
# Generating Hash 53/200...
# Generating Hash 54/200...
# Generating Hash 55/200...
# Generating Hash 56/200...
# Generating Hash 57/200...
# Generating Hash 58/200...
# Generating Hash 59/200...
# Generating Hash 60/200...
# Generating Hash 61/200...
# Generating Hash 62/200...
# Generating Hash 63/200...
# Generating Hash 64/200...
# Generating Hash 65/200...
# Generating Hash 66/200...
# Generating Hash 67/200...
# Generating Hash 68/200...
# Generating Hash 69/200...
# Generating Hash 70/200...
# Generating Hash 71/200...
# Generating Hash 72/200...
# Generating Hash 73/200...
# Generating Hash 74/200...
# Generating Hash 75/200...
# Generating Hash 76/200...
# Generating Hash 77/200...
# Generating Hash 78/200...
# Generating Hash 79/200...
# Generating Hash 80/200...
# Generating Hash 81/200...
# Generating Hash 82/200...
# Generating Hash 83/200...
# Generating Hash 84/200...
# Generating Hash 85/200...
# Generating Hash 86/200...
# Generating Hash 87/200...
# Generating Hash 88/200...
# Generating Hash 89/200...
# Generating Hash 90/200...
# Generating Hash 91/200...
# Generating Hash 92/200...
# Generating Hash 93/200...
# Generating Hash 94/200...
# Generating Hash 95/200...
# Generating Hash 96/200...
# Generating Hash 97/200...
# Generating Hash 98/200...
# Generating Hash 99/200...
# Generating Hash 100/200...
# Generating Hash 101/200...
# Generating Hash 102/200...
# Generating Hash 103/200...
# Generating Hash 104/200...
# Generating Hash 105/200...
# Generating Hash 106/200...
# Generating Hash 107/200...
# Generating Hash 108/200...
# Generating Hash 109/200...
# Generating Hash 110/200...
# Generating Hash 111/200...
# Generating Hash 112/200...
# Generating Hash 113/200...
# Generating Hash 114/200...
# Generating Hash 115/200...
# Generating Hash 116/200...
# Generating Hash 117/200...
# Generating Hash 118/200...
# Generating Hash 119/200...
# Generating Hash 120/200...
# Generating Hash 121/200...
# Generating Hash 122/200...
# Generating Hash 123/200...
# Generating Hash 124/200...
# Generating Hash 125/200...
# Generating Hash 126/200...
# Generating Hash 127/200...
# Generating Hash 128/200...
# Generating Hash 129/200...
# Generating Hash 130/200...
# Generating Hash 131/200...
# Generating Hash 132/200...
# Generating Hash 133/200...
# Generating Hash 134/200...
# Generating Hash 135/200...
# Generating Hash 136/200...
# Generating Hash 137/200...
# Generating Hash 138/200...
# Generating Hash 139/200...
# Generating Hash 140/200...
# Generating Hash 141/200...
# Generating Hash 142/200...
# Generating Hash 143/200...
# Generating Hash 144/200...
# Generating Hash 145/200...
# Generating Hash 146/200...
# Generating Hash 147/200...
# Generating Hash 148/200...
# Generating Hash 149/200...
# Generating Hash 150/200...
# Generating Hash 151/200...
# Generating Hash 152/200...
# Generating Hash 153/200...
# Generating Hash 154/200...
# Generating Hash 155/200...
# Generating Hash 156/200...
# Generating Hash 157/200...
# Generating Hash 158/200...
# Generating Hash 159/200...
# Generating Hash 160/200...
# Generating Hash 161/200...
# Generating Hash 162/200...
# Generating Hash 163/200...
# Generating Hash 164/200...
# Generating Hash 165/200...
# Generating Hash 166/200...
# Generating Hash 167/200...
# Generating Hash 168/200...
# Generating Hash 169/200...
# Generating Hash 170/200...
# Generating Hash 171/200...
# Generating Hash 172/200...
# Generating Hash 173/200...
# Generating Hash 174/200...
# Generating Hash 175/200...
# Generating Hash 176/200...
# Generating Hash 177/200...
# Generating Hash 178/200...
# Generating Hash 179/200...
# Generating Hash 180/200...
# Generating Hash 181/200...
# Generating Hash 182/200...
# Generating Hash 183/200...
# Generating Hash 184/200...
# Generating Hash 185/200...
# Generating Hash 186/200...
# Generating Hash 187/200...
# Generating Hash 188/200...
# Generating Hash 189/200...
# Generating Hash 190/200...
# Generating Hash 191/200...
# Generating Hash 192/200...
# Generating Hash 193/200...
# Generating Hash 194/200...
# Generating Hash 195/200...
# Generating Hash 196/200...
# Generating Hash 197/200...
# Generating Hash 198/200...
# Generating Hash 199/200...
# Generating Hash 200/200...
# saving fingerprints in fingerprint/target_address.data...
# fingerprints saved

# %%
# Generate fingerprint of the query data to match. If the fingerprint exists, it will load that directly instead of generating
# Also, the idetification results will be produced in .txt file

aid.audioIdentification(queryDir, fingerprintDir, output_file)
# Out:
# Loading fingerprints(target_address.data) in folder 'fingerprint'...
# C:\Users\xiede\OneDrive\MisterDK\Queen Mary University of London\Courses\Music Informatics\Assignment\02.Audio Identification\audioidentification.py:113: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   coordinates = peak_local_max(np.log(D), min_distance=min_distance, threshold_rel=0.05, indices=False)
# Generating query Contellation Map 1/213...
# Generating query Contellation Map 2/213...
# Generating query Contellation Map 3/213...
# Generating query Contellation Map 4/213...
# Generating query Contellation Map 5/213...
# Generating query Contellation Map 6/213...
# Generating query Contellation Map 7/213...
# Generating query Contellation Map 8/213...
# Generating query Contellation Map 9/213...
# Generating query Contellation Map 10/213...
# Generating query Contellation Map 11/213...
# Generating query Contellation Map 12/213...
# Generating query Contellation Map 13/213...
# Generating query Contellation Map 14/213...
# Generating query Contellation Map 15/213...
# Generating query Contellation Map 16/213...
# Generating query Contellation Map 17/213...
# Generating query Contellation Map 18/213...
# Generating query Contellation Map 19/213...
# Generating query Contellation Map 20/213...
# Generating query Contellation Map 21/213...
# Generating query Contellation Map 22/213...
# Generating query Contellation Map 23/213...
# Generating query Contellation Map 24/213...
# Generating query Contellation Map 25/213...
# Generating query Contellation Map 26/213...
# Generating query Contellation Map 27/213...
# Generating query Contellation Map 28/213...
# Generating query Contellation Map 29/213...
# Generating query Contellation Map 30/213...
# Generating query Contellation Map 31/213...
# Generating query Contellation Map 32/213...
# Generating query Contellation Map 33/213...
# Generating query Contellation Map 34/213...
# Generating query Contellation Map 35/213...
# Generating query Contellation Map 36/213...
# Generating query Contellation Map 37/213...
# Generating query Contellation Map 38/213...
# Generating query Contellation Map 39/213...
# Generating query Contellation Map 40/213...
# Generating query Contellation Map 41/213...
# Generating query Contellation Map 42/213...
# Generating query Contellation Map 43/213...
# Generating query Contellation Map 44/213...
# Generating query Contellation Map 45/213...
# Generating query Contellation Map 46/213...
# Generating query Contellation Map 47/213...
# Generating query Contellation Map 48/213...
# Generating query Contellation Map 49/213...
# Generating query Contellation Map 50/213...
# Generating query Contellation Map 51/213...
# Generating query Contellation Map 52/213...
# Generating query Contellation Map 53/213...
# Generating query Contellation Map 54/213...
# Generating query Contellation Map 55/213...
# Generating query Contellation Map 56/213...
# Generating query Contellation Map 57/213...
# Generating query Contellation Map 58/213...
# Generating query Contellation Map 59/213...
# Generating query Contellation Map 60/213...
# Generating query Contellation Map 61/213...
# Generating query Contellation Map 62/213...
# Generating query Contellation Map 63/213...
# Generating query Contellation Map 64/213...
# Generating query Contellation Map 65/213...
# Generating query Contellation Map 66/213...
# Generating query Contellation Map 67/213...
# Generating query Contellation Map 68/213...
# Generating query Contellation Map 69/213...
# Generating query Contellation Map 70/213...
# Generating query Contellation Map 71/213...
# Generating query Contellation Map 72/213...
# Generating query Contellation Map 73/213...
# Generating query Contellation Map 74/213...
# Generating query Contellation Map 75/213...
# Generating query Contellation Map 76/213...
# Generating query Contellation Map 77/213...
# Generating query Contellation Map 78/213...
# Generating query Contellation Map 79/213...
# Generating query Contellation Map 80/213...
# Generating query Contellation Map 81/213...
# Generating query Contellation Map 82/213...
# Generating query Contellation Map 83/213...
# Generating query Contellation Map 84/213...
# Generating query Contellation Map 85/213...
# Generating query Contellation Map 86/213...
# Generating query Contellation Map 87/213...
# Generating query Contellation Map 88/213...
# Generating query Contellation Map 89/213...
# Generating query Contellation Map 90/213...
# Generating query Contellation Map 91/213...
# Generating query Contellation Map 92/213...
# Generating query Contellation Map 93/213...
# Generating query Contellation Map 94/213...
# Generating query Contellation Map 95/213...
# Generating query Contellation Map 96/213...
# Generating query Contellation Map 97/213...
# Generating query Contellation Map 98/213...
# Generating query Contellation Map 99/213...
# Generating query Contellation Map 100/213...
# Generating query Contellation Map 101/213...
# Generating query Contellation Map 102/213...
# Generating query Contellation Map 103/213...
# Generating query Contellation Map 104/213...
# Generating query Contellation Map 105/213...
# Generating query Contellation Map 106/213...
# Generating query Contellation Map 107/213...
# Generating query Contellation Map 108/213...
# Generating query Contellation Map 109/213...
# Generating query Contellation Map 110/213...
# Generating query Contellation Map 111/213...
# Generating query Contellation Map 112/213...
# Generating query Contellation Map 113/213...
# Generating query Contellation Map 114/213...
# Generating query Contellation Map 115/213...
# Generating query Contellation Map 116/213...
# Generating query Contellation Map 117/213...
# Generating query Contellation Map 118/213...
# Generating query Contellation Map 119/213...
# Generating query Contellation Map 120/213...
# Generating query Contellation Map 121/213...
# Generating query Contellation Map 122/213...
# Generating query Contellation Map 123/213...
# Generating query Contellation Map 124/213...
# Generating query Contellation Map 125/213...
# Generating query Contellation Map 126/213...
# Generating query Contellation Map 127/213...
# Generating query Contellation Map 128/213...
# Generating query Contellation Map 129/213...
# Generating query Contellation Map 130/213...
# Generating query Contellation Map 131/213...
# Generating query Contellation Map 132/213...
# Generating query Contellation Map 133/213...
# Generating query Contellation Map 134/213...
# Generating query Contellation Map 135/213...
# Generating query Contellation Map 136/213...
# Generating query Contellation Map 137/213...
# Generating query Contellation Map 138/213...
# Generating query Contellation Map 139/213...
# Generating query Contellation Map 140/213...
# Generating query Contellation Map 141/213...
# Generating query Contellation Map 142/213...
# Generating query Contellation Map 143/213...
# Generating query Contellation Map 144/213...
# Generating query Contellation Map 145/213...
# Generating query Contellation Map 146/213...
# Generating query Contellation Map 147/213...
# Generating query Contellation Map 148/213...
# Generating query Contellation Map 149/213...
# Generating query Contellation Map 150/213...
# Generating query Contellation Map 151/213...
# Generating query Contellation Map 152/213...
# Generating query Contellation Map 153/213...
# Generating query Contellation Map 154/213...
# Generating query Contellation Map 155/213...
# Generating query Contellation Map 156/213...
# Generating query Contellation Map 157/213...
# Generating query Contellation Map 158/213...
# Generating query Contellation Map 159/213...
# Generating query Contellation Map 160/213...
# Generating query Contellation Map 161/213...
# Generating query Contellation Map 162/213...
# Generating query Contellation Map 163/213...
# Generating query Contellation Map 164/213...
# Generating query Contellation Map 165/213...
# Generating query Contellation Map 166/213...
# Generating query Contellation Map 167/213...
# Generating query Contellation Map 168/213...
# Generating query Contellation Map 169/213...
# Generating query Contellation Map 170/213...
# Generating query Contellation Map 171/213...
# Generating query Contellation Map 172/213...
# Generating query Contellation Map 173/213...
# Generating query Contellation Map 174/213...
# Generating query Contellation Map 175/213...
# Generating query Contellation Map 176/213...
# Generating query Contellation Map 177/213...
# Generating query Contellation Map 178/213...
# Generating query Contellation Map 179/213...
# Generating query Contellation Map 180/213...
# Generating query Contellation Map 181/213...
# Generating query Contellation Map 182/213...
# Generating query Contellation Map 183/213...
# Generating query Contellation Map 184/213...
# Generating query Contellation Map 185/213...
# Generating query Contellation Map 186/213...
# Generating query Contellation Map 187/213...
# Generating query Contellation Map 188/213...
# Generating query Contellation Map 189/213...
# Generating query Contellation Map 190/213...
# Generating query Contellation Map 191/213...
# Generating query Contellation Map 192/213...
# Generating query Contellation Map 193/213...
# Generating query Contellation Map 194/213...
# Generating query Contellation Map 195/213...
# Generating query Contellation Map 196/213...
# Generating query Contellation Map 197/213...
# Generating query Contellation Map 198/213...
# Generating query Contellation Map 199/213...
# Generating query Contellation Map 200/213...
# Generating query Contellation Map 201/213...
# Generating query Contellation Map 202/213...
# Generating query Contellation Map 203/213...
# Generating query Contellation Map 204/213...
# Generating query Contellation Map 205/213...
# Generating query Contellation Map 206/213...
# Generating query Contellation Map 207/213...
# Generating query Contellation Map 208/213...
# Generating query Contellation Map 209/213...
# Generating query Contellation Map 210/213...
# Generating query Contellation Map 211/213...
# Generating query Contellation Map 212/213...
# Generating query Contellation Map 213/213...
# Generating Query Hash 1/213...
# Query: classical.00000-snippet-10-0
# Sorry, the query finger is empty
#
# Generating Query Hash 2/213...
# Query: classical.00000-snippet-10-10
# ['classical.00000', 'classical.00089', 'classical.00002']
#  [(0, 168), (89, 162), (2, 140)]
#
# Generating Query Hash 3/213...
# Query: classical.00000-snippet-10-20
# ['classical.00000', 'classical.00042', 'classical.00002']
#  [(0, 228), (42, 99), (2, 86)]
#
# Generating Query Hash 4/213...
# Query: classical.00003-snippet-10-0
# ['classical.00099', 'classical.00089', 'classical.00059']
#  [(99, 61), (89, 49), (59, 39)]
#
# Generating Query Hash 5/213...
# Query: classical.00003-snippet-10-10
# ['classical.00053', 'classical.00083', 'classical.00061']
#  [(53, 6), (83, 5), (61, 5)]
#
# Generating Query Hash 6/213...
# Query: classical.00003-snippet-10-20
# ['classical.00056', 'classical.00096', 'pop.00024']
#  [(56, 15), (96, 10), (124, 10)]
#
# Generating Query Hash 7/213...
# Query: classical.00004-snippet-10-0
# ['classical.00097', 'classical.00004', 'classical.00073']
#  [(97, 49), (4, 47), (73, 39)]
#
# Generating Query Hash 8/213...
# Query: classical.00004-snippet-10-10
# ['classical.00004', 'classical.00045', 'classical.00042']
#  [(4, 93), (45, 68), (42, 59)]
#
# Generating Query Hash 9/213...
# Query: classical.00005-snippet-10-0
# ['classical.00025', 'classical.00059', 'classical.00023']
#  [(25, 11), (59, 10), (23, 9)]
#
# Generating Query Hash 10/213...
# Query: classical.00005-snippet-10-10
# ['classical.00097', 'classical.00005', 'classical.00042']
#  [(97, 31), (5, 31), (42, 27)]
#
# Generating Query Hash 11/213...
# Query: classical.00005-snippet-10-20
# ['classical.00005', 'classical.00097', 'classical.00025']
#  [(5, 56), (97, 29), (25, 27)]
#
# Generating Query Hash 12/213...
# Query: classical.00009-snippet-10-0
# ['classical.00002', 'classical.00097', 'classical.00068']
#  [(2, 39), (97, 39), (68, 33)]
#
# Generating Query Hash 13/213...
# Query: classical.00009-snippet-10-10
# ['classical.00024', 'classical.00025', 'classical.00096']
#  [(24, 25), (25, 23), (96, 22)]
#
# Generating Query Hash 14/213...
# Query: classical.00009-snippet-10-20
# ['classical.00061', 'classical.00085', 'classical.00024']
#  [(61, 43), (85, 39), (24, 37)]
#
# Generating Query Hash 15/213...
# Query: classical.00010-snippet-10-0
# ['classical.00010', 'classical.00053', 'classical.00005']
#  [(10, 199), (53, 67), (5, 64)]
#
# Generating Query Hash 16/213...
# Query: classical.00010-snippet-10-10
# ['classical.00010', 'classical.00085', 'classical.00025']
#  [(10, 67), (85, 39), (25, 31)]
#
# Generating Query Hash 17/213...
# Query: classical.00010-snippet-10-20
# ['classical.00010', 'classical.00025', 'classical.00043']
#  [(10, 207), (25, 72), (43, 51)]
#
# Generating Query Hash 18/213...
# Query: classical.00011-snippet-10-0
# ['classical.00011', 'classical.00069', 'classical.00059']
#  [(11, 58), (69, 40), (59, 36)]
#
# Generating Query Hash 19/213...
# Query: classical.00011-snippet-10-10
# ['classical.00098', 'classical.00049', 'classical.00060']
#  [(98, 78), (49, 76), (60, 68)]
#
# Generating Query Hash 20/213...
# Query: classical.00012-snippet-10-0
# ['classical.00012', 'classical.00068', 'classical.00098']
#  [(12, 222), (68, 119), (98, 108)]
#
# Generating Query Hash 21/213...
# Query: classical.00012-snippet-10-10
# ['classical.00012', 'classical.00069', 'classical.00098']
#  [(12, 213), (69, 143), (98, 120)]
#
# Generating Query Hash 22/213...
# Query: classical.00012-snippet-10-20
# ['classical.00097', 'classical.00042', 'classical.00096']
#  [(97, 76), (42, 74), (96, 58)]
#
# Generating Query Hash 23/213...
# Query: classical.00013-snippet-10-0
# ['classical.00056', 'classical.00013', 'classical.00096']
#  [(56, 309), (13, 172), (96, 170)]
#
# Generating Query Hash 24/213...
# Query: classical.00013-snippet-10-10
# ['classical.00056', 'classical.00013', 'classical.00049']
#  [(56, 164), (13, 146), (49, 92)]
#
# Generating Query Hash 25/213...
# Query: classical.00013-snippet-10-20
# ['classical.00013', 'classical.00049', 'classical.00069']
#  [(13, 317), (49, 146), (69, 113)]
#
# Generating Query Hash 26/213...
# Query: classical.00014-snippet-10-0
# ['pop.00023', 'pop.00055', 'classical.00056']
#  [(123, 30), (155, 28), (56, 21)]
#
# Generating Query Hash 27/213...
# Query: classical.00014-snippet-10-10
# ['classical.00014', 'classical.00056', 'classical.00096']
#  [(14, 39), (56, 38), (96, 33)]
#
# Generating Query Hash 28/213...
# Query: classical.00014-snippet-10-20
# ['classical.00099', 'classical.00053', 'pop.00069']
#  [(99, 58), (53, 44), (169, 43)]
#
# Generating Query Hash 29/213...
# Query: classical.00015-snippet-10-0
# ['classical.00099', 'pop.00069', 'classical.00056']
#  [(99, 57), (169, 53), (56, 47)]
#
# Generating Query Hash 30/213...
# Query: classical.00015-snippet-10-10
# ['classical.00099', 'classical.00015', 'classical.00017']
#  [(99, 34), (15, 22), (17, 20)]
#
# Generating Query Hash 31/213...
# Query: classical.00015-snippet-10-20
# ['classical.00089', 'pop.00069', 'classical.00099']
#  [(89, 67), (169, 50), (99, 48)]
#
# Generating Query Hash 32/213...
# Query: classical.00019-snippet-10-0
# ['classical.00021', 'classical.00070', 'classical.00075']
#  [(21, 6), (70, 6), (75, 6)]
#
# Generating Query Hash 33/213...
# Query: classical.00019-snippet-10-10
# ['classical.00053', 'pop.00003', 'pop.00040']
#  [(53, 34), (103, 30), (140, 30)]
#
# Generating Query Hash 34/213...
# Query: classical.00019-snippet-10-20
# ['classical.00002', 'classical.00042', 'classical.00056']
#  [(2, 50), (42, 45), (56, 43)]
#
# Generating Query Hash 35/213...
# Query: classical.00020-snippet-10-0
# ['classical.00074', 'classical.00018', 'classical.00076']
#  [(74, 5), (18, 4), (76, 4)]
#
# Generating Query Hash 36/213...
# Query: classical.00020-snippet-10-10
# ['classical.00020', 'classical.00068', 'classical.00086']
#  [(20, 143), (68, 71), (86, 57)]
#
# Generating Query Hash 37/213...
# Query: classical.00020-snippet-10-20
# ['classical.00020', 'classical.00076', 'classical.00086']
#  [(20, 117), (76, 78), (86, 66)]
#
# Generating Query Hash 38/213...
# Query: classical.00024-snippet-10-0
# ['classical.00024', 'classical.00069', 'classical.00085']
#  [(24, 129), (69, 48), (85, 46)]
#
# Generating Query Hash 39/213...
# Query: classical.00024-snippet-10-10
# ['classical.00024', 'classical.00056', 'classical.00069']
#  [(24, 323), (56, 98), (69, 78)]
#
# Generating Query Hash 40/213...
# Query: classical.00024-snippet-10-20
# ['classical.00024', 'classical.00076', 'classical.00025']
#  [(24, 286), (76, 83), (25, 72)]
#
# Generating Query Hash 41/213...
# Query: classical.00025-snippet-10-0
# ['classical.00025', 'classical.00057', 'classical.00010']
#  [(25, 52), (57, 36), (10, 32)]
#
# Generating Query Hash 42/213...
# Query: classical.00025-snippet-10-10
# ['classical.00025', 'classical.00053', 'classical.00024']
#  [(25, 495), (53, 164), (24, 97)]
#
# Generating Query Hash 43/213...
# Query: classical.00025-snippet-10-20
# ['classical.00025', 'classical.00010', 'classical.00043']
#  [(25, 301), (10, 61), (43, 55)]
#
# Generating Query Hash 44/213...
# Query: classical.00034-snippet-10-0
# ['classical.00034', 'classical.00098', 'classical.00053']
#  [(34, 333), (98, 40), (53, 40)]
#
# Generating Query Hash 45/213...
# Query: classical.00034-snippet-10-10
# ['classical.00034', 'classical.00056', 'classical.00046']
#  [(34, 141), (56, 58), (46, 47)]
#
# Generating Query Hash 46/213...
# Query: classical.00034-snippet-10-20
# ['classical.00056', 'classical.00046', 'classical.00059']
#  [(56, 47), (46, 41), (59, 41)]
#
# Generating Query Hash 47/213...
# Query: classical.00035-snippet-10-0
# ['classical.00035', 'classical.00089', 'classical.00099']
#  [(35, 297), (89, 133), (99, 113)]
#
# Generating Query Hash 48/213...
# Query: classical.00035-snippet-10-10
# ['classical.00035', 'classical.00042', 'classical.00097']
#  [(35, 290), (42, 64), (97, 59)]
#
# Generating Query Hash 49/213...
# Query: classical.00035-snippet-10-20
# ['classical.00035', 'classical.00042', 'classical.00002']
#  [(35, 127), (42, 92), (2, 79)]
#
# Generating Query Hash 50/213...
# Query: classical.00039-snippet-10-0
# ['classical.00087', 'classical.00078', 'classical.00040']
#  [(87, 8), (78, 8), (40, 7)]
#
# Generating Query Hash 51/213...
# Query: classical.00039-snippet-10-10
# ['classical.00042', 'classical.00059', 'classical.00097']
#  [(42, 38), (59, 30), (97, 30)]
#
# Generating Query Hash 52/213...
# Query: classical.00039-snippet-10-20
# ['classical.00042', 'classical.00090', 'classical.00097']
#  [(42, 34), (90, 33), (97, 29)]
#
# Generating Query Hash 53/213...
# Query: classical.00040-snippet-10-0
# ['classical.00027', 'classical.00085', 'classical.00006']
#  [(27, 15), (85, 13), (6, 10)]
#
# Generating Query Hash 54/213...
# Query: classical.00040-snippet-10-10
# ['classical.00069', 'classical.00020', 'classical.00042']
#  [(69, 37), (20, 32), (42, 32)]
#
# Generating Query Hash 55/213...
# Query: classical.00044-snippet-10-0
# ['classical.00097', 'classical.00042', 'classical.00060']
#  [(97, 40), (42, 39), (60, 39)]
#
# Generating Query Hash 56/213...
# Query: classical.00044-snippet-10-10
# ['classical.00020', 'classical.00076', 'classical.00044']
#  [(20, 57), (76, 49), (44, 46)]
#
# Generating Query Hash 57/213...
# Query: classical.00044-snippet-10-20
# ['classical.00099', 'classical.00002', 'classical.00085']
#  [(99, 44), (2, 41), (85, 41)]
#
# Generating Query Hash 58/213...
# Query: classical.00045-snippet-10-0
# ['classical.00045', 'classical.00097', 'classical.00093']
#  [(45, 121), (97, 77), (93, 67)]
#
# Generating Query Hash 59/213...
# Query: classical.00045-snippet-10-10
# ['classical.00045', 'classical.00042', 'classical.00097']
#  [(45, 195), (42, 128), (97, 105)]
#
# Generating Query Hash 60/213...
# Query: classical.00045-snippet-10-20
# ['classical.00045', 'classical.00097', 'classical.00047']
#  [(45, 178), (97, 115), (47, 95)]
#
# Generating Query Hash 61/213...
# Query: classical.00049-snippet-10-0
# ['classical.00049', 'classical.00056', 'classical.00069']
#  [(49, 927), (56, 188), (69, 178)]
#
# Generating Query Hash 62/213...
# Query: classical.00049-snippet-10-10
# ['classical.00049', 'classical.00056', 'classical.00068']
#  [(49, 799), (56, 223), (68, 198)]
#
# Generating Query Hash 63/213...
# Query: classical.00049-snippet-10-20
# ['classical.00049', 'classical.00069', 'classical.00056']
#  [(49, 720), (69, 113), (56, 93)]
#
# Generating Query Hash 64/213...
# Query: classical.00050-snippet-10-0
# ['classical.00083', 'classical.00076', 'classical.00019']
#  [(83, 14), (76, 14), (19, 12)]
#
# Generating Query Hash 65/213...
# Query: classical.00050-snippet-10-10
# ['classical.00050', 'classical.00024', 'classical.00069']
#  [(50, 72), (24, 49), (69, 44)]
#
# Generating Query Hash 66/213...
# Query: classical.00050-snippet-10-20
# ['classical.00050', 'classical.00069', 'classical.00068']
#  [(50, 629), (69, 72), (68, 67)]
#
# Generating Query Hash 67/213...
# Query: classical.00054-snippet-10-0
# ['pop.00014', 'pop.00030', 'pop.00069']
#  [(114, 68), (130, 67), (169, 61)]
#
# Generating Query Hash 68/213...
# Query: classical.00054-snippet-10-10
# ['pop.00073', 'pop.00044', 'pop.00098']
#  [(173, 72), (144, 70), (198, 66)]
#
# Generating Query Hash 69/213...
# Query: classical.00054-snippet-10-20
# ['classical.00098', 'pop.00014', 'pop.00018']
#  [(98, 62), (114, 61), (118, 51)]
#
# Generating Query Hash 70/213...
# Query: classical.00055-snippet-10-0
# ['pop.00059', 'pop.00002', 'pop.00038']
#  [(159, 107), (102, 100), (138, 94)]
#
# Generating Query Hash 71/213...
# Query: classical.00055-snippet-10-10
# ['classical.00053', 'pop.00001', 'pop.00055']
#  [(53, 87), (101, 66), (155, 63)]
#
# Generating Query Hash 72/213...
# Query: classical.00055-snippet-10-20
# ['pop.00077', 'pop.00072', 'pop.00043']
#  [(177, 61), (172, 59), (143, 57)]
#
# Generating Query Hash 73/213...
# Query: classical.00059-snippet-10-0
# ['classical.00059', 'classical.00070', 'classical.00097']
#  [(59, 51), (70, 28), (97, 27)]
#
# Generating Query Hash 74/213...
# Query: classical.00059-snippet-10-10
# ['classical.00059', 'classical.00047', 'classical.00081']
#  [(59, 125), (47, 63), (81, 42)]
#
# Generating Query Hash 75/213...
# Query: classical.00059-snippet-10-20
# ['classical.00059', 'classical.00069', 'classical.00097']
#  [(59, 53), (69, 33), (97, 30)]
#
# Generating Query Hash 76/213...
# Query: classical.00060-snippet-10-0
# ['classical.00060', 'classical.00073', 'classical.00012']
#  [(60, 278), (73, 82), (12, 82)]
#
# Generating Query Hash 77/213...
# Query: classical.00060-snippet-10-10
# ['classical.00060', 'pop.00077', 'pop.00069']
#  [(60, 551), (177, 81), (169, 68)]
#
# Generating Query Hash 78/213...
# Query: classical.00060-snippet-10-20
# ['classical.00060', 'classical.00061', 'classical.00056']
#  [(60, 222), (61, 65), (56, 51)]
#
# Generating Query Hash 79/213...
# Query: classical.00064-snippet-10-0
# ['classical.00010', 'classical.00047', 'classical.00011']
#  [(10, 9), (47, 8), (11, 8)]
#
# Generating Query Hash 80/213...
# Query: classical.00064-snippet-10-10
# ['classical.00046', 'classical.00064', 'classical.00059']
#  [(46, 30), (64, 30), (59, 28)]
#
# Generating Query Hash 81/213...
# Query: classical.00064-snippet-10-20
# ['classical.00025', 'classical.00093', 'classical.00007']
#  [(25, 36), (93, 31), (7, 29)]
#
# Generating Query Hash 82/213...
# Query: classical.00065-snippet-10-0
# ['classical.00014', 'classical.00056', 'classical.00097']
#  [(14, 14), (56, 13), (97, 12)]
#
# Generating Query Hash 83/213...
# Query: classical.00065-snippet-10-10
# ['classical.00065', 'classical.00014', 'classical.00011']
#  [(65, 21), (14, 15), (11, 14)]
#
# Generating Query Hash 84/213...
# Query: classical.00065-snippet-10-20
# ['classical.00025', 'classical.00045', 'classical.00099']
#  [(25, 37), (45, 35), (99, 30)]
#
# Generating Query Hash 85/213...
# Query: classical.00069-snippet-10-0
# ['classical.00069', 'classical.00098', 'classical.00068']
#  [(69, 184), (98, 115), (68, 102)]
#
# Generating Query Hash 86/213...
# Query: classical.00069-snippet-10-10
# ['classical.00069', 'classical.00056', 'classical.00068']
#  [(69, 110), (56, 107), (68, 93)]
#
# Generating Query Hash 87/213...
# Query: classical.00069-snippet-10-20
# ['classical.00042', 'classical.00097', 'classical.00069']
#  [(42, 70), (97, 57), (69, 54)]
#
# Generating Query Hash 88/213...
# Query: classical.00070-snippet-10-0
# ['classical.00070', 'classical.00069', 'classical.00068']
#  [(70, 534), (69, 130), (68, 127)]
#
# Generating Query Hash 89/213...
# Query: classical.00070-snippet-10-10
# ['classical.00070', 'classical.00068', 'classical.00076']
#  [(70, 71), (68, 69), (76, 67)]
#
# Generating Query Hash 90/213...
# Query: classical.00070-snippet-10-20
# ['classical.00053', 'classical.00042', 'classical.00025']
#  [(53, 73), (42, 66), (25, 63)]
#
# Generating Query Hash 91/213...
# Query: classical.00074-snippet-10-0
# ['pop.00068', 'pop.00043', 'pop.00033']
#  [(168, 72), (143, 60), (133, 55)]
#
# Generating Query Hash 92/213...
# Query: classical.00074-snippet-10-10
# ['pop.00062', 'classical.00049', 'classical.00053']
#  [(162, 73), (49, 70), (53, 66)]
#
# Generating Query Hash 93/213...
# Query: classical.00074-snippet-10-20
# ['pop.00030', 'classical.00053', 'pop.00015']
#  [(130, 79), (53, 77), (115, 76)]
#
# Generating Query Hash 94/213...
# Query: classical.00075-snippet-10-0
# ['classical.00046', 'classical.00096', 'classical.00099']
#  [(46, 62), (96, 60), (99, 59)]
#
# Generating Query Hash 95/213...
# Query: classical.00075-snippet-10-10
# ['pop.00062', 'pop.00055', 'pop.00076']
#  [(162, 72), (155, 72), (176, 66)]
#
# Generating Query Hash 96/213...
# Query: classical.00075-snippet-10-20
# ['classical.00089', 'classical.00053', 'classical.00099']
#  [(89, 72), (53, 66), (99, 62)]
#
# Generating Query Hash 97/213...
# Query: classical.00079-snippet-10-0
# ['classical.00056', 'pop.00023', 'classical.00049']
#  [(56, 148), (123, 79), (49, 71)]
#
# Generating Query Hash 98/213...
# Query: classical.00079-snippet-10-10
# ['classical.00056', 'classical.00006', 'classical.00061']
#  [(56, 40), (6, 37), (61, 34)]
#
# Generating Query Hash 99/213...
# Query: classical.00079-snippet-10-20
# ['classical.00087', 'classical.00001', 'classical.00099']
#  [(87, 17), (1, 14), (99, 11)]
#
# Generating Query Hash 100/213...
# Query: classical.00080-snippet-10-0
# ['classical.00042', 'classical.00025', 'classical.00002']
#  [(42, 38), (25, 34), (2, 30)]
#
# Generating Query Hash 101/213...
# Query: classical.00080-snippet-10-10
# ['classical.00081', 'classical.00050', 'classical.00045']
#  [(81, 15), (50, 12), (45, 12)]
#
# Generating Query Hash 102/213...
# Query: classical.00080-snippet-10-20
# ['pop.00028', 'pop.00015', 'pop.00058']
#  [(128, 59), (115, 48), (158, 47)]
#
# Generating Query Hash 103/213...
# Query: classical.00084-snippet-10-0
# ['pop.00059', 'pop.00056', 'pop.00068']
#  [(159, 139), (156, 131), (168, 102)]
#
# Generating Query Hash 104/213...
# Query: classical.00084-snippet-10-10
# ['pop.00043', 'pop.00093', 'pop.00089']
#  [(143, 81), (193, 79), (189, 78)]
#
# Generating Query Hash 105/213...
# Query: classical.00084-snippet-10-20
# ['pop.00030', 'pop.00001', 'pop.00031']
#  [(130, 118), (101, 100), (131, 95)]
#
# Generating Query Hash 106/213...
# Query: classical.00085-snippet-10-0
# ['classical.00085', 'pop.00019', 'classical.00049']
#  [(85, 163), (119, 133), (49, 112)]
#
# Generating Query Hash 107/213...
# Query: classical.00085-snippet-10-10
# ['pop.00093', 'pop.00022', 'pop.00043']
#  [(193, 147), (122, 139), (143, 138)]
#
# Generating Query Hash 108/213...
# Query: classical.00085-snippet-10-20
# ['pop.00095', 'pop.00089', 'pop.00001']
#  [(195, 142), (189, 131), (101, 125)]
#
# Generating Query Hash 109/213...
# Query: pop.00000-snippet-10-0
# ['pop.00000', 'classical.00056', 'classical.00099']
#  [(100, 193), (56, 90), (99, 74)]
#
# Generating Query Hash 110/213...
# Query: pop.00000-snippet-10-10
# ['pop.00000', 'pop.00093', 'pop.00002']
#  [(100, 166), (193, 136), (102, 92)]
#
# Generating Query Hash 111/213...
# Query: pop.00000-snippet-10-20
# ['pop.00000', 'pop.00059', 'pop.00056']
#  [(100, 248), (159, 120), (156, 120)]
#
# Generating Query Hash 112/213...
# Query: pop.00003-snippet-10-0
# ['pop.00003', 'pop.00037', 'pop.00036']
#  [(103, 145), (137, 78), (136, 72)]
#
# Generating Query Hash 113/213...
# Query: pop.00003-snippet-10-10
# ['pop.00003', 'pop.00069', 'classical.00053']
#  [(103, 182), (169, 99), (53, 83)]
#
# Generating Query Hash 114/213...
# Query: pop.00003-snippet-10-20
# ['pop.00003', 'classical.00056', 'classical.00049']
#  [(103, 230), (56, 99), (49, 89)]
#
# Generating Query Hash 115/213...
# Query: pop.00004-snippet-10-0
# ['pop.00028', 'pop.00097', 'pop.00020']
#  [(128, 163), (197, 129), (120, 109)]
#
# Generating Query Hash 116/213...
# Query: pop.00004-snippet-10-10
# ['pop.00028', 'pop.00022', 'pop.00023']
#  [(128, 201), (122, 186), (123, 180)]
#
# Generating Query Hash 117/213...
# Query: pop.00005-snippet-10-0
# ['classical.00053', 'classical.00096', 'pop.00043']
#  [(53, 40), (96, 37), (143, 33)]
#
# Generating Query Hash 118/213...
# Query: pop.00005-snippet-10-10
# ['pop.00005', 'pop.00019', 'pop.00093']
#  [(105, 208), (119, 73), (193, 72)]
#
# Generating Query Hash 119/213...
# Query: pop.00009-snippet-10-0
# ['pop.00009', 'pop.00020', 'pop.00023']
#  [(109, 2398), (120, 342), (123, 304)]
#
# Generating Query Hash 120/213...
# Query: pop.00009-snippet-10-10
# ['pop.00009', 'pop.00020', 'pop.00023']
#  [(109, 2941), (120, 345), (123, 325)]
#
# Generating Query Hash 121/213...
# Query: pop.00010-snippet-10-0
# ['pop.00010', 'pop.00078', 'classical.00097']
#  [(110, 703), (178, 59), (97, 55)]
#
# Generating Query Hash 122/213...
# Query: pop.00010-snippet-10-10
# ['pop.00010', 'pop.00028', 'pop.00055']
#  [(110, 323), (128, 144), (155, 142)]
#
# Generating Query Hash 123/213...
# Query: pop.00010-snippet-10-20
# ['pop.00010', 'pop.00057', 'pop.00078']
#  [(110, 458), (157, 77), (178, 76)]
#
# Generating Query Hash 124/213...
# Query: pop.00011-snippet-10-0
# ['classical.00042', 'classical.00069', 'classical.00027']
#  [(42, 25), (69, 25), (27, 24)]
#
# Generating Query Hash 125/213...
# Query: pop.00011-snippet-10-10
# ['pop.00011', 'classical.00069', 'classical.00056']
#  [(111, 147), (69, 94), (56, 75)]
#
# Generating Query Hash 126/213...
# Query: pop.00011-snippet-10-20
# ['pop.00011', 'classical.00068', 'classical.00069']
#  [(111, 341), (68, 69), (69, 67)]
#
# Generating Query Hash 127/213...
# Query: pop.00012-snippet-10-0
# ['pop.00012', 'classical.00069', 'classical.00024']
#  [(112, 227), (69, 54), (24, 52)]
#
# Generating Query Hash 128/213...
# Query: pop.00012-snippet-10-10
# ['pop.00012', 'classical.00056', 'classical.00053']
#  [(112, 150), (56, 64), (53, 46)]
#
# Generating Query Hash 129/213...
# Query: pop.00012-snippet-10-20
# ['pop.00012', 'classical.00056', 'classical.00053']
#  [(112, 284), (56, 54), (53, 51)]
#
# Generating Query Hash 130/213...
# Query: pop.00013-snippet-10-0
# ['pop.00013', 'pop.00069', 'classical.00045']
#  [(113, 113), (169, 28), (45, 26)]
#
# Generating Query Hash 131/213...
# Query: pop.00013-snippet-10-10
# ['pop.00013', 'classical.00098', 'classical.00069']
#  [(113, 199), (98, 48), (69, 37)]
#
# Generating Query Hash 132/213...
# Query: pop.00013-snippet-10-20
# ['pop.00013', 'classical.00056', 'classical.00068']
#  [(113, 113), (56, 62), (68, 41)]
#
# Generating Query Hash 133/213...
# Query: pop.00014-snippet-10-0
# ['pop.00014', 'pop.00001', 'pop.00069']
#  [(114, 251), (101, 71), (169, 65)]
#
# Generating Query Hash 134/213...
# Query: pop.00014-snippet-10-10
# ['pop.00014', 'pop.00056', 'pop.00059']
#  [(114, 355), (156, 64), (159, 55)]
#
# Generating Query Hash 135/213...
# Query: pop.00014-snippet-10-20
# ['pop.00014', 'pop.00077', 'pop.00069']
#  [(114, 224), (177, 56), (169, 53)]
#
# Generating Query Hash 136/213...
# Query: pop.00015-snippet-10-0
# ['pop.00015', 'pop.00022', 'pop.00037']
#  [(115, 909), (122, 645), (137, 342)]
#
# Generating Query Hash 137/213...
# Query: pop.00015-snippet-10-10
# ['pop.00022', 'pop.00015', 'pop.00037']
#  [(122, 955), (115, 803), (137, 342)]
#
# Generating Query Hash 138/213...
# Query: pop.00015-snippet-10-20
# ['pop.00015', 'pop.00022', 'pop.00037']
#  [(115, 808), (122, 502), (137, 233)]
#
# Generating Query Hash 139/213...
# Query: pop.00019-snippet-10-0
# ['classical.00056', 'classical.00069', 'classical.00024']
#  [(56, 90), (69, 73), (24, 72)]
#
# Generating Query Hash 140/213...
# Query: pop.00019-snippet-10-10
# ['classical.00056', 'classical.00085', 'classical.00069']
#  [(56, 72), (85, 56), (69, 50)]
#
# Generating Query Hash 141/213...
# Query: pop.00019-snippet-10-20
# ['classical.00056', 'classical.00028', 'classical.00049']
#  [(56, 102), (28, 71), (49, 63)]
#
# Generating Query Hash 142/213...
# Query: pop.00020-snippet-10-0
# ['classical.00015', 'classical.00047', 'classical.00074']
#  [(15, 5), (47, 5), (74, 3)]
#
# Generating Query Hash 143/213...
# Query: pop.00020-snippet-10-10
# ['classical.00076', 'classical.00099', 'classical.00088']
#  [(76, 37), (99, 34), (88, 34)]
#
# Generating Query Hash 144/213...
# Query: pop.00020-snippet-10-20
# ['classical.00076', 'classical.00049', 'classical.00020']
#  [(76, 54), (49, 53), (20, 50)]
#
# Generating Query Hash 145/213...
# Query: pop.00024-snippet-10-0
# ['pop.00024', 'pop.00065', 'pop.00079']
#  [(124, 143), (165, 64), (179, 61)]
#
# Generating Query Hash 146/213...
# Query: pop.00024-snippet-10-10
# ['pop.00024', 'classical.00002', 'classical.00099']
#  [(124, 333), (2, 72), (99, 62)]
#
# Generating Query Hash 147/213...
# Query: pop.00025-snippet-10-0
# ['pop.00025', 'classical.00042', 'pop.00003']
#  [(125, 91), (42, 38), (103, 27)]
#
# Generating Query Hash 148/213...
# Query: pop.00025-snippet-10-10
# ['pop.00025', 'classical.00002', 'classical.00024']
#  [(125, 522), (2, 48), (24, 41)]
#
# Generating Query Hash 149/213...
# Query: pop.00025-snippet-10-20
# ['pop.00025', 'classical.00056', 'classical.00046']
#  [(125, 470), (56, 82), (46, 69)]
#
# Generating Query Hash 150/213...
# Query: pop.00034-snippet-10-0
# ['pop.00034', 'pop.00023', 'pop.00032']
#  [(134, 2852), (123, 451), (132, 369)]
#
# Generating Query Hash 151/213...
# Query: pop.00034-snippet-10-10
# ['pop.00034', 'pop.00023', 'pop.00021']
#  [(134, 2238), (123, 403), (121, 358)]
#
# Generating Query Hash 152/213...
# Query: pop.00034-snippet-10-20
# ['pop.00034', 'pop.00089', 'pop.00023']
#  [(134, 940), (189, 349), (123, 342)]
#
# Generating Query Hash 153/213...
# Query: pop.00035-snippet-10-0
# ['pop.00035', 'pop.00020', 'pop.00021']
#  [(135, 4293), (120, 2071), (121, 774)]
#
# Generating Query Hash 154/213...
# Query: pop.00035-snippet-10-10
# ['pop.00035', 'pop.00020', 'pop.00021']
#  [(135, 1713), (120, 1337), (121, 650)]
#
# Generating Query Hash 155/213...
# Query: pop.00035-snippet-10-20
# ['pop.00035', 'pop.00020', 'pop.00021']
#  [(135, 3204), (120, 1224), (121, 592)]
#
# Generating Query Hash 156/213...
# Query: pop.00039-snippet-10-0
# ['classical.00028', 'classical.00085', 'classical.00084']
#  [(28, 18), (85, 16), (84, 15)]
#
# Generating Query Hash 157/213...
# Query: pop.00039-snippet-10-10
# ['pop.00039', 'classical.00046', 'pop.00069']
#  [(139, 629), (46, 55), (169, 45)]
#
# Generating Query Hash 158/213...
# Query: pop.00039-snippet-10-20
# ['pop.00039', 'classical.00099', 'classical.00046']
#  [(139, 204), (99, 47), (46, 43)]
#
# Generating Query Hash 159/213...
# Query: pop.00040-snippet-10-0
# ['classical.00083', 'classical.00087', 'classical.00084']
#  [(83, 7), (87, 6), (84, 5)]
#
# Generating Query Hash 160/213...
# Query: pop.00040-snippet-10-10
# ['pop.00040', 'pop.00081', 'classical.00020']
#  [(140, 138), (181, 37), (20, 37)]
#
# Generating Query Hash 161/213...
# Query: pop.00044-snippet-10-0
# ['pop.00044', 'classical.00046', 'classical.00096']
#  [(144, 81), (46, 51), (96, 50)]
#
# Generating Query Hash 162/213...
# Query: pop.00044-snippet-10-10
# ['classical.00046', 'classical.00056', 'pop.00044']
#  [(46, 72), (56, 69), (144, 65)]
#
# Generating Query Hash 163/213...
# Query: pop.00044-snippet-10-20
# ['pop.00044', 'classical.00053', 'pop.00069']
#  [(144, 200), (53, 87), (169, 81)]
#
# Generating Query Hash 164/213...
# Query: pop.00045-snippet-10-0
# ['pop.00046', 'classical.00099', 'classical.00005']
#  [(146, 49), (99, 46), (5, 35)]
#
# Generating Query Hash 165/213...
# Query: pop.00045-snippet-10-10
# ['pop.00046', 'pop.00045', 'classical.00098']
#  [(146, 81), (145, 73), (98, 70)]
#
# Generating Query Hash 166/213...
# Query: pop.00045-snippet-10-20
# ['pop.00045', 'pop.00046', 'classical.00060']
#  [(145, 160), (146, 121), (60, 80)]
#
# Generating Query Hash 167/213...
# Query: pop.00049-snippet-10-0
# ['pop.00049', 'pop.00079', 'classical.00099']
#  [(149, 162), (179, 49), (99, 48)]
#
# Generating Query Hash 168/213...
# Query: pop.00049-snippet-10-10
# ['pop.00049', 'classical.00096', 'pop.00079']
#  [(149, 755), (96, 49), (179, 44)]
#
# Generating Query Hash 169/213...
# Query: pop.00049-snippet-10-20
# ['pop.00049', 'classical.00076', 'classical.00096']
#  [(149, 247), (76, 45), (96, 45)]
#
# Generating Query Hash 170/213...
# Query: pop.00050-snippet-10-0
# ['pop.00050', 'classical.00004', 'classical.00042']
#  [(150, 387), (4, 36), (42, 36)]
#
# Generating Query Hash 171/213...
# Query: pop.00050-snippet-10-10
# ['pop.00050', 'classical.00099', 'classical.00002']
#  [(150, 76), (99, 31), (2, 30)]
#
# Generating Query Hash 172/213...
# Query: pop.00050-snippet-10-20
# ['pop.00050', 'classical.00099', 'classical.00000']
#  [(150, 166), (99, 65), (0, 56)]
#
# Generating Query Hash 173/213...
# Query: pop.00054-snippet-10-0
# ['pop.00054', 'pop.00060', 'pop.00089']
#  [(154, 1134), (160, 1134), (189, 108)]
#
# Generating Query Hash 174/213...
# Query: pop.00054-snippet-10-10
# ['pop.00054', 'pop.00060', 'pop.00036']
#  [(154, 665), (160, 665), (136, 139)]
#
# Generating Query Hash 175/213...
# Query: pop.00054-snippet-10-20
# ['pop.00054', 'pop.00060', 'pop.00028']
#  [(154, 609), (160, 609), (128, 129)]
#
# Generating Query Hash 176/213...
# Query: pop.00055-snippet-10-0
# ['pop.00055', 'pop.00023', 'pop.00032']
#  [(155, 522), (123, 131), (132, 102)]
#
# Generating Query Hash 177/213...
# Query: pop.00055-snippet-10-10
# ['pop.00055', 'pop.00097', 'pop.00023']
#  [(155, 296), (197, 156), (123, 151)]
#
# Generating Query Hash 178/213...
# Query: pop.00055-snippet-10-20
# ['pop.00055', 'pop.00023', 'pop.00097']
#  [(155, 228), (123, 189), (197, 135)]
#
# Generating Query Hash 179/213...
# Query: pop.00059-snippet-10-0
# ['pop.00059', 'pop.00056', 'pop.00019']
#  [(159, 5898), (156, 4910), (119, 217)]
#
# Generating Query Hash 180/213...
# Query: pop.00059-snippet-10-10
# ['pop.00059', 'pop.00056', 'pop.00019']
#  [(159, 8023), (156, 7629), (119, 383)]
#
# Generating Query Hash 181/213...
# Query: pop.00059-snippet-10-20
# ['pop.00059', 'pop.00056', 'pop.00019']
#  [(159, 6211), (156, 5483), (119, 302)]
#
# Generating Query Hash 182/213...
# Query: pop.00060-snippet-10-0
# ['pop.00054', 'pop.00060', 'pop.00023']
#  [(154, 1667), (160, 1667), (123, 118)]
#
# Generating Query Hash 183/213...
# Query: pop.00060-snippet-10-10
# ['pop.00054', 'pop.00060', 'pop.00036']
#  [(154, 604), (160, 604), (136, 84)]
#
# Generating Query Hash 184/213...
# Query: pop.00060-snippet-10-20
# ['pop.00054', 'pop.00060', 'pop.00032']
#  [(154, 2146), (160, 2146), (132, 189)]
#
# Generating Query Hash 185/213...
# Query: pop.00064-snippet-10-0
# ['pop.00064', 'classical.00024', 'classical.00053']
#  [(164, 544), (24, 44), (53, 42)]
#
# Generating Query Hash 186/213...
# Query: pop.00064-snippet-10-10
# ['pop.00064', 'classical.00098', 'classical.00073']
#  [(164, 940), (98, 36), (73, 34)]
#
# Generating Query Hash 187/213...
# Query: pop.00064-snippet-10-20
# ['pop.00064', 'pop.00068', 'pop.00070']
#  [(164, 1057), (168, 78), (170, 58)]
#
# Generating Query Hash 188/213...
# Query: pop.00065-snippet-10-0
# ['pop.00065', 'classical.00050', 'classical.00076']
#  [(165, 377), (50, 89), (76, 78)]
#
# Generating Query Hash 189/213...
# Query: pop.00065-snippet-10-10
# ['pop.00065', 'classical.00069', 'classical.00068']
#  [(165, 592), (69, 104), (68, 101)]
#
# Generating Query Hash 190/213...
# Query: pop.00065-snippet-10-20
# ['pop.00065', 'classical.00085', 'classical.00056']
#  [(165, 143), (85, 47), (56, 46)]
#
# Generating Query Hash 191/213...
# Query: pop.00069-snippet-10-0
# ['pop.00069', 'classical.00042', 'classical.00099']
#  [(169, 525), (42, 89), (99, 84)]
#
# Generating Query Hash 192/213...
# Query: pop.00069-snippet-10-10
# ['pop.00069', 'classical.00042', 'classical.00053']
#  [(169, 827), (42, 84), (53, 81)]
#
# Generating Query Hash 193/213...
# Query: pop.00069-snippet-10-20
# ['pop.00069', 'classical.00042', 'classical.00053']
#  [(169, 571), (42, 77), (53, 65)]
#
# Generating Query Hash 194/213...
# Query: pop.00070-snippet-10-0
# ['pop.00070', 'classical.00053', 'classical.00059']
#  [(170, 239), (53, 70), (59, 51)]
#
# Generating Query Hash 195/213...
# Query: pop.00070-snippet-10-10
# ['pop.00070', 'classical.00053', 'classical.00042']
#  [(170, 151), (53, 69), (42, 64)]
#
# Generating Query Hash 196/213...
# Query: pop.00070-snippet-10-20
# ['pop.00070', 'classical.00053', 'classical.00056']
#  [(170, 207), (53, 80), (56, 79)]
#
# Generating Query Hash 197/213...
# Query: pop.00074-snippet-10-0
# ['pop.00074', 'pop.00038', 'pop.00097']
#  [(174, 418), (138, 101), (197, 100)]
#
# Generating Query Hash 198/213...
# Query: pop.00074-snippet-10-10
# ['pop.00074', 'pop.00002', 'pop.00087']
#  [(174, 391), (102, 117), (187, 111)]
#
# Generating Query Hash 199/213...
# Query: pop.00074-snippet-10-20
# ['pop.00074', 'pop.00097', 'pop.00068']
#  [(174, 350), (197, 97), (168, 95)]
#
# Generating Query Hash 200/213...
# Query: pop.00075-snippet-10-0
# ['pop.00075', 'pop.00096', 'pop.00002']
#  [(175, 394), (196, 113), (102, 92)]
#
# Generating Query Hash 201/213...
# Query: pop.00075-snippet-10-10
# ['pop.00075', 'pop.00056', 'pop.00028']
#  [(175, 776), (156, 141), (128, 130)]
#
# Generating Query Hash 202/213...
# Query: pop.00075-snippet-10-20
# ['pop.00075', 'pop.00059', 'pop.00056']
#  [(175, 537), (159, 125), (156, 122)]
#
# Generating Query Hash 203/213...
# Query: pop.00079-snippet-10-0
# ['classical.00096', 'classical.00042', 'classical.00059']
#  [(96, 50), (42, 45), (59, 42)]
#
# Generating Query Hash 204/213...
# Query: pop.00079-snippet-10-10
# ['pop.00024', 'pop.00038', 'pop.00054']
#  [(124, 81), (138, 71), (154, 70)]
#
# Generating Query Hash 205/213...
# Query: pop.00079-snippet-10-20
# ['pop.00079', 'classical.00099', 'pop.00067']
#  [(179, 49), (99, 44), (167, 44)]
#
# Generating Query Hash 206/213...
# Query: pop.00080-snippet-10-0
# ['pop.00047', 'pop.00080', 'pop.00022']
#  [(147, 485), (180, 366), (122, 79)]
#
# Generating Query Hash 207/213...
# Query: pop.00080-snippet-10-10
# ['pop.00047', 'pop.00080', 'pop.00096']
#  [(147, 203), (180, 103), (196, 49)]
#
# Generating Query Hash 208/213...
# Query: pop.00080-snippet-10-20
# ['pop.00080', 'pop.00047', 'pop.00082']
#  [(180, 257), (147, 131), (182, 71)]
#
# Generating Query Hash 209/213...
# Query: pop.00084-snippet-10-0
# ['pop.00084', 'pop.00018', 'pop.00056']
#  [(184, 751), (118, 98), (156, 95)]
#
# Generating Query Hash 210/213...
# Query: pop.00084-snippet-10-10
# ['pop.00084', 'pop.00097', 'pop.00015']
#  [(184, 1047), (197, 179), (115, 148)]
#
# Generating Query Hash 211/213...
# Query: pop.00085-snippet-10-0
# ['pop.00085', 'pop.00098', 'pop.00043']
#  [(185, 465), (198, 136), (143, 131)]
#
# Generating Query Hash 212/213...
# Query: pop.00085-snippet-10-10
# ['pop.00085', 'pop.00093', 'pop.00091']
#  [(185, 324), (193, 136), (191, 125)]
#
# Generating Query Hash 213/213...
# Query: pop.00085-snippet-10-20
# ['pop.00085', 'pop.00095', 'pop.00036']
#  [(185, 333), (195, 116), (136, 113)]
#
# Finished
